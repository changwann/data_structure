# %% [markdown]
# # 1. Python Primmer

# %% [markdown]
# print() returns "None"

# %%
print(print(1))
# Out:
# 1
# None

# %% [markdown]
# print(type()) prints "<class 'type'>"

# %%
x = 2.5
print(type(x))

t = True
print(type(t))
# Out:
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# "/" is different from "//"

# %%
z = 10   #if z = 10.0, all prints <class 'float'>
print(z // 3, type(z // 3))
print(z / 3, type(z / 3))
print(z % 3, type(z % 3))
# Out:
# 3 <class 'int'>
# 3.3333333333333335 <class 'float'>
# 1 <class 'int'>

# %% [markdown]
# In bool data type, 0 means False and not zero means True.
#
# -> 논리 연산자에서 결과값은 숫자 우선으로 나온다! + 숫자끼리는 가장 마지막에 컴퓨터가 체크한 숫자로

# %%
print(True and 0) # False(X) 0(O) --> 결과의 의미는 False로 같지만 표현이 다를 뿐!
# Out:
# 0
